# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()

# %%
df= pd.read_csv("data2.csv")
df
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
cuantitativas = df.iloc[:,2:]
cuantitativas
# Out:
#     ventas_precios_corrientes  ventas_precios_constantes  \
# 0                     27858.9                    27477.3
# 1                     25994.2                    25223.4
# 2                     27780.0                    26334.3
# 3                     29134.3                    27045.9
# 4                     27969.0                    25631.9
# ..                        ...                        ...
# 60                   154517.1                    45463.4
# 61                   152202.6                    23802.1
# 62                       16.5                    24612.4
# 63                   177148.1                    24140.5
# 64                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 0                 2.785887e+07  2.759173e+07     2.671420e+05
# 1                 2.599420e+07  2.574918e+07     2.450208e+05
# 2                 2.778001e+07  2.747223e+07     3.077778e+05
# ...

# %%
cualitativas = df.iloc[:,[0,1]]
cualitativas
# Out:
#     Unnamed: 0 indice_tiempo
# 0            0    01/01/2017
# 1            1    01/02/2017
# 2            2    01/03/2017
# 3            3    01/04/2017
# 4            4    01/05/2017
# ..         ...           ...
# 60          60    01/01/2022
# 61          61    01/02/2022
# 62          62    01/03/2022
# 63          63    01/04/2022
# 64          64    01/05/2022
#
# [65 rows x 2 columns]

# %%
y=cuantitativas
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido ventas_precios_corrientes              2.143126e+05
# ventas_precios_constantes              4.002291e+04
# ventas_totales_canal_venta             2.074407e+08
# salon_ventas                           1.976066e+08
# canales_on_line                        7.623053e+06
# ventas_totales_medio_pago              2.059531e+08
# efectivo                               6.191160e+07
# tarjetas_debito                        5.882176e+07
# tarjetas_credito                       7.417776e+07
# otros_medios                           1.557117e+07
# ventas_totales_grupo_articulos         2.059531e+08
# subtotal_ventas_alimentos_bebidas      1.430213e+08
# bebidas                                2.659026e+07
# almacen                                5.498569e+07
# panaderia                              6.939510e+06
# lacteos                                2.659026e+07
# carnes                                 2.522386e+07
# verduleria_fruteria                    7.570093e+06
# ...

# %%
Dato_or= cuantitativas[(y<=Limite_Superior)&(y>=Limite_Inferior)]
Dato_or
# Out:
#     ventas_precios_corrientes  ventas_precios_constantes  \
# 0                     27858.9                    27477.3
# 1                     25994.2                    25223.4
# 2                     27780.0                    26334.3
# 3                     29134.3                    27045.9
# 4                     27969.0                    25631.9
# ..                        ...                        ...
# 60                   154517.1                        NaN
# 61                   152202.6                    23802.1
# 62                       16.5                    24612.4
# 63                   177148.1                    24140.5
# 64                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 0                 2.785887e+07  2.759173e+07     2.671420e+05
# 1                 2.599420e+07  2.574918e+07     2.450208e+05
# 2                 2.778001e+07  2.747223e+07     3.077778e+05
# ...

# %%
data_clean=Dato_or.copy()
data_clean=data_clean.fillna(round(Dato_or.mean(),1))
data_clean
# Out:
#     ventas_precios_corrientes  ventas_precios_constantes  \
# 0                     27858.9                    27477.3
# 1                     25994.2                    25223.4
# 2                     27780.0                    26334.3
# 3                     29134.3                    27045.9
# 4                     27969.0                    25631.9
# ..                        ...                        ...
# 60                   154517.1                    25363.3
# 61                   152202.6                    23802.1
# 62                       16.5                    24612.4
# 63                   177148.1                    24140.5
# 64                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 0                 2.785887e+07  2.759173e+07     2.671420e+05
# 1                 2.599420e+07  2.574918e+07     2.450208e+05
# 2                 2.778001e+07  2.747223e+07     3.077778e+05
# ...

# %%
Da_fi = pd.concat([cualitativas, data_clean], axis=1)
Da_fi
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
Da_fi.to_csv("data3.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-49a32bcc0cbd> in <cell line: 1>()
# ----> 1 Da_fi.to_csv("data3.csv")
#
# NameError: name 'Da_fi' is not defined

# %%
from google.colab import files
files.download("data3.csv")
